# %% [markdown]
# <a href="https://colab.research.google.com/github/Gnanamrutha2007/numpy-practice/blob/main/mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

months=np.array(["jan","feb","march","april","may","june","july","august","sep","october","november","dec"])
sales=[]
print("enter the sales (in $1000) for each month")
for month in months:
  value=float(input(f"{month}:"))
  sales.append(value)
sales=np.array(sales)

print("\n-------Company Sales anyalisis-----")
print("\n Total sales of the year: ",np.sum(sales),"$")
print("\n Average monthly sales : ",np.mean(sales))
print("\n Highest sales:",np.max(sales))
print("\n Lowest sales: ",np.min(sales))
best_month=months[np.argmax(sales)]
worst_month=months[np.argmin(sales)]

print("best Month: ",best_month,months[np.argmax(sales)])
print("worst Month: ",worst_month)

above_avg=months[sales>np.mean(sales)]
below_avg=months[sales<np.mean(sales)]

print("Above average months: ",above_avg)
print("below average months: ",below_avg)

print("\n how much each month differs from the average: ")
differnce=sales-np.mean(sales)
print(differnce)
# Out:
# enter the sales (in $1000) for each month
# jan:12
# feb:30
# march:40
# april:32
# may:54
# june:36
# july:58
# august:26
# sep:43
# october:56
# november:76
# dec:89
#
# -------Company Sales anyalisis-----
#
#  Total sales of the year:  552.0 $
#
#  Average monthly sales :  46.0
#
#  Highest sales: 89.0
#
#  Lowest sales:  12.0
# best Month:  dec dec
# worst Month:  jan
# Above average months:  ['may' 'july' 'october' 'november' 'dec']
# below average months:  ['jan' 'feb' 'march' 'april' 'june' 'august' 'sep']
#
#  how much each month differs from the average:
# [-34. -16.  -6. -14.   8. -10.  12. -20.  -3.  10.  30.  43.]
